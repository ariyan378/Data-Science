# %% [markdown]
# #1 . Print

# %%
print('Hello Data Science')
# Out:
# Hello Data Science

# %%
print(1,2,3,54,6,)
# Out:
# 1 2 3 54 6

# %%
print('ami','tmi' ,sep='-')
# Out:
# ami-tmi

# %%
print('Hello' , end='-')
print('World')
# Out:
# Hello-World

# %% [markdown]
# # 2 . Data Types

# %%
print(1e309)
print(1e308)
# Out:
# inf
# 1e+308

# %%
print(8.55)
print(1.7e308)
print(1.7e309)
# Out:
# 8.55
# 1.7e+308
# inf

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
print("My Name Is Data Analyst Hridoy")
# Out:
# My Name Is Data Analyst Hridoy

# %%
print(5+6j)
# Out:
# (5+6j)

# %%
#list

print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuples

print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary

print({'Name':'Hridoy',
       'Role':'Data Analyst'})
# Out:
# {'Name': 'Hridoy', 'Role': 'Data Analyst'}

# %%
type([1,2,3,4,5])
# Out:
# list

# %%
type(6+7j)
# Out:
# complex

# %% [markdown]
# # 3. Variable

# %%
#Container Of Future Use

# %%
Name = 'Ariyan Islam Hridoy'
print(Name)
# Out:
# Ariyan Islam Hridoy

# %%
a = 10
b = 50

print(a*b)
# Out:
# 500

# %%
#Dynamic Typing
#Where we do not tell The data type.Python Do It By There Own-python
#Static Typing -Oposite-c,c++

# %%
#Dynamic Binding can hold many data type in a same Data==python
#static -opsite==c,c++

a = 5
print(a)
a='Ariyan islam'
print(a)
# Out:
# 5
# Ariyan islam

# %%
a,b,c =1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # 4. Comments

# %%
#Single Line Comments

# %%
#Always Above Code
#Try TO Add Comments For Every Operation

# %% [markdown]
# # 5. KeyWords

# %%
#only '_' can be use as an identifier
#we canot start with digit

# %%
_1 = 1
print(_1)
# Out:
# 1

# %%
#identifier can't be a keyword

# %% [markdown]
# # 6.User Input

# %%
Ariyan = str(input("Enter Your Name :"))

print(Ariyan)
# Out:
# Enter Your Name :1
# 1

# %%
input("Name")
# Out:
# NameAriyan Islam Hridoy
# 'Ariyan Islam Hridoy'

# %%
#Think The ALgorithm
#write These Step In Comment

# %%
#Take Input From User and store them In a variable
a = int(input("Enter Your Number :"))
b = int(input("Enter Your Number : "))
#Add and Print Them
print(a+b)
# Out:
# Enter Your Number :1
# Enter Your Number : 1
# 2

# %% [markdown]
# # 7. Type Conversion

# %%
#implicit

print(1+1.2)
print(type(1),type(1.2))
# Out:
# 2.2
# <class 'int'> <class 'float'>

# %%
#Explicit
#WE defined the Data Type Early for this reason '1'convert to int

int('1')
int(23.2)
# Out:
# 23

# %%
str(123456789)
# Out:
# '123456789'

# %%
float(12)
# Out:
# 12.0

# %%
#Take Input From User and store them In a variable
a = int(input("Enter Your Number :"))
b = int(input("Enter Your Number : "))
#Add and Print Them
print(a+b)

print(type(a))
# Out:
# Enter Your Number :11
# Enter Your Number : 1
# 12
# <class 'int'>

# %% [markdown]
# #  8. Literals

# %%
from typing import Literal
#The Raw Value We store In a Variable Is Called Litrals

a=0b1010 #Binary Litreal ob
b= 1 #int literal

d=0x12c #Hexadecimal Literal 0x
f =0o310 # Octal Literal 0o
e = 3.14j # Complex Literal

#Float

c=1.2 #Float Literal
g = 1.3e2 # 1.3 * 10^ 2
h = 1.3e-2 # 1.3*10^-2
print(a,b,c,d)
# Out:
# 10 1 1.2 300

# %%
print(h)
# Out:
# 0.013

# %%
x=3.14j

print(x,x.imag,x.real)
# Out:
# 3.14j 3.14 0.0

# %%
from re import MULTILINE
string = 'This Is Himu'
strings = "This Is Data Analyst Himu"
char = 'This Is Hridoy'
Multiline_Str = '''This is Cudlingpong
                    Himu'''
unicode = u"\U0001f606"

raw_str = r'Raw\n String'

print(unicode)
# Out:
# 😆

# %%
#Boolean

a = True + 1  # True == +1
b = False +10 # False == -1

print('a:',a,'b:',b)
# Out:
# a: 2 b: 10

# %%
a = None
print(a)

#python doesnt give us the benefit to decalare variable without value.for this reason we use None
# Out:
# None
