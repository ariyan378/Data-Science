# %%
#in python ,strings are a unicode character

# %%
#create
s='hello'
s="hello"
s='''hello'''#for multiline string
s ="""hello"""
s=str(12345)
print(s)
# Out:
# 12345

# %%
"it's raining outside"
# Out:
# "it's raining outside"

# %%
# positive Indexing
s = 'hello data'
print(s[0])
# Out:
# h

# %%
#Negative indexing

s='hello hridoy'
print(s[-1])
# Out:
# y

# %%
#slicing
s='hello world'
print(s[0:5])
# Out:
# hello

# %%
print(s[:])
# Out:
# hello world

# %%
print(s[:7])
# Out:
# hello w

# %%
print(s[2:8:2])
# Out:
# low

# %%
print(s[::-1])#reverse a string
# Out:
# dlrow olleh

# %%
print(s[-5:])
# Out:
# world

# %%
print(s[-1:-6:-1])
# Out:
# dlrow

# %%
#editing
#python string are imutable

# %%
#deleting

del s

# %%
#operation in string

print('Ariyan'+' '+'Islam'+' '+'Hridoy')
# Out:
# Ariyan Islam Hridoy

# %%
print('Hridoy'*10,end=' ')
# Out:
# HridoyHridoyHridoyHridoyHridoyHridoyHridoyHridoyHridoyHridoy

# %%
#only multiply and + work .for arithmatic

# %%
'hridoy'=='hridoy'
# Out:
# True

# %%
'hridoy'>'hridoy'

#lexiographically comparison
# Out:
# False

# %%
'hello' and 'world'
# Out:
# 'world'

# %%
'hello' or 'world'
# Out:
# 'hello'

# %%
'' and 'world'
# Out:
# ''

# %%
'' or 'world'
# Out:
# 'world'

# %%
not 'world'
# Out:
# False

# %%
for i in 'hello':
    print(i)
# Out:
# h
# e
# l
# l
# o

# %%
for i in 'dhaka':#len of dhaka === 5
    print('hridoy')
# Out:
# hridoy
# hridoy
# hridoy
# hridoy
# hridoy

# %%
'd' in 'dhaka'
# Out:
# True

# %%
'A' in 'Hridoy'
# Out:
# False

# %%
###Common function

# %%
#len
#max
#min
#sorted

# %%
len('ariyan')
# Out:
# 6

# %%
max('Hello world') # maximum basis on ascii value
# Out:
# 'w'

# %%
min('ariyan')
# Out:
# 'a'

# %%
sorted('Ariyan Islam Hridoy')
# Out:
# [' ',
#  ' ',
#  'A',
#  'H',
#  'I',
#  'a',
#  'a',
#  'd',
#  'i',
#  'i',
#  'l',
#  'm',
#  'n',
#  'o',
#  'r',
#  'r',
#  's',
#  'y',
#  'y']

# %%
s='ariyan'
s.capitalize()
# Out:
# 'Ariyan'

# %%
s.upper()
# Out:
# 'ARIYAN'

# %%
s.lower()
# Out:
# 'ariyan'

# %%
s='ariyan islam hridoy'
s.title()
# Out:
# 'Ariyan Islam Hridoy'

# %%
'hello himu'.swapcase()#capital to lower and lower to upper
# Out:
# 'HELLO HIMU'

# %%
'heloo'.count('o')
# Out:
# 2

# %%
'hello find'.find('o')
# Out:
# 4

# %%
'my name is hridoy'.index('h')
# Out:
# 11

# %%
'my name is hridoy'.endswith('y')
# Out:
# True

# %%
'my name is hridoy'.startswith('y')
# Out:
# False

# %%
#format

name = 'hridoy'
gender = 'male'

'hi my name is  {}'.format(name)
# Out:
# 'hi my name is  hridoy'

# %%
s='j'
s.isalpha()
s.isnumeric()
# Out:
# False

# %%
'1name'.isidentifier()
# Out:
# False

# %%
#split

s = 'Ariyan Islam Hridoy'
print(s.split())
# Out:
# ['Ariyan', 'Islam', 'Hridoy']

# %%
print(s.split('i'))
# Out:
# ['ru', 'eh g', 'uehtg u', 'ehgbuhr tu', ' hvg']

# %%
#join

Ariyan =' '.join(['Ariyan', 'Islam', 'Hridoy'])

# %%
print(Ariyan)
# Out:
# Ariyan Islam Hridoy

# %%
Ariyan.replace("Hridoy",'Himu')
# Out:
# 'Ariyan Islam Himu'

# %%
#strip

'  Himu'.strip()#remove White Space
# Out:
# 'Himu'
